# %%
import os
import pandas as pd
import numpy as np
import altair as alt

from scipy.stats import fisher_exact
from math import log

# %%
TSS_bedcols = ['chr', 'TSS500up', 'TSS500down', 'Gene_Name']

# %%
def __simi_mat(tflist, escape_dir):
    
    mat = pd.DataFrame(index=tflist, columns=tflist)
    dice_mat = pd.DataFrame(index=tflist, columns=tflist)
    
    tflist_pop = tflist.copy()
    for t in tflist:
        tfile = pd.read_table(os.path.join(escape_dir, t + ".bed.gz"), names=TSS_bedcols)
        #print('t =', t)s

        if tfile.shape[0] == 0:
            mat.loc[t] = np.nan
            mat.loc[:, t] = np.nan

            dice_mat.loc[t] = np.nan
            dice_mat.loc[:, t] = np.nan

            tflist_pop.pop(0)
            continue

        for t2 in tflist_pop:
            t2file = pd.read_table(os.path.join(escape_dir, t2 + ".bed.gz"), names=TSS_bedcols)
            #print('t2 = ', t2)

            if t2file.shape[0] == 0:
                mat.loc[t, t2] = np.nan
                mat.loc[t2, t] = np.nan

                dice_mat.loc[t, t2] = np.nan
                dice_mat.loc[t2, t] = np.nan

            else:
                inner = tfile.merge(t2file, how='inner').shape[0]

                union_size = tfile.shape[0] + t2file.shape[0] - inner
                sim = inner / union_size
                mat.loc[t, t2] = sim
                mat.loc[t2, t] = sim

                dice_sim = (2 * inner) / (tfile.shape[0] + t2file.shape[0])
                dice_mat.loc[t, t2] = dice_sim
                dice_mat.loc[t2, t] = dice_sim


        tflist_pop.pop(0)
    
    mat = mat.astype(float)
    np.fill_diagonal(mat.values, 1.01)

    dice_mat = dice_mat.astype(float)
    np.fill_diagonal(dice_mat.values, 1.01)
        
    return mat, dice_mat

# %%
meta = pd.read_table('./db/meta_tfs.tsv')
remap2022_TFs = meta['TF_Name'].tolist()

escapeoverlapdir = './ReMap2022_Overlap/ReMap2022_Escape/'
bgoverlapdir = './ReMap2022_Overlap/ReMap2022_BG/'

tss_summary = pd.read_table('./summary/tss_overlapescape_2022.tsv', sep='\t')
remap2022_TSStfs = tss_summary.query('enriched == True')['TF'].tolist()
remap2022_strongTFs = ['HSF1', 'ZFP36', 'NIPBL', 'MYB', 'STAT1']

# %%
tf_pairs = []
tflist2 = remap2022_TFs.copy()
for tf in remap2022_TFs:
    tflist2.pop(0)
    for tf1 in tflist2:
        s = sorted([tf, tf1])
        tf_pairs.append(s)

# %%
sim_allvsall, dice_allvsall = __simi_mat(remap2022_TFs, escapeoverlapdir)
hm_simava = sim_allvsall.melt(ignore_index=False).reset_index()
hm_diceava = dice_allvsall.melt(ignore_index=False).reset_index()

# %%
alt.hconcat(
    alt.Chart(hm_simava.query('variable == @remap2022_TSStfs & index == @remap2022_TSStfs')).mark_rect().encode(
    alt.X('variable', title='TFs'),
    alt.Y('index', title="TFs"),
    alt.Color('value', title='index'),
    alt.Tooltip(['index', 'variable','value'])
).properties(height=300, width=300),
    alt.Chart(hm_diceava.query('variable == @remap2022_TSStfs & index == @remap2022_TSStfs')).mark_rect().encode(
    alt.X('variable', title='TFs'),
    alt.Y('index', title="TFs"),
    alt.Color('value', title='index'),
    alt.Tooltip(['index', 'variable','value'])
).properties(height=300, width=300)
)
# Out:
# alt.HConcatChart(...)

# %%
sim_bg_allvsall, dice_bg_allvsall = __simi_mat(remap2022_TFs, bgoverlapdir)
hm_simbgava = sim_bg_allvsall.melt(ignore_index=False).reset_index()
hm_dicebgava = dice_bg_allvsall.melt(ignore_index=False).reset_index()

# %%
alt.hconcat(
alt.Chart(hm_simbgava.query('variable == @remap2022_TSStfs & index == @remap2022_TSStfs')).mark_rect().encode(
    alt.X('variable', title='TFs'),
    alt.Y('index', title="TFs"),
    alt.Color('value', title='index'),
    alt.Tooltip(['index', 'variable','value'])
).properties(height=300, width=300), 
alt.Chart(hm_dicebgava.query('variable == @remap2022_TSStfs & index == @remap2022_TSStfs')).mark_rect().encode(
    alt.X('variable', title='TFs'),
    alt.Y('index', title="TFs"),
    alt.Color('value', title='index'),
    alt.Tooltip(['index', 'variable','value'])
).properties(height=300, width=300)
)
# Out:
# alt.HConcatChart(...)

# %%
sim_foreoverbg = sim_allvsall / sim_bg_allvsall
dice_foreoverbg = dice_allvsall / dice_bg_allvsall
hm_esoverbg = sim_foreoverbg.melt(ignore_index=False).reset_index()
hm_diceesoverbg = dice_foreoverbg.melt(ignore_index=False).reset_index()

alt.hconcat(
    alt.Chart(hm_esoverbg.query('variable == @remap2022_TSStfs & index == @remap2022_strongTFs')).mark_rect().encode(
    alt.X('variable', title='TFs'),
    alt.Y('index', title="TFs"),
    alt.Color('value', title='es/bg'),
    alt.Tooltip(['index', 'variable','value'])
).properties(height=300, width=300),
alt.Chart(hm_diceesoverbg.query('variable == @remap2022_TSStfs & index == @remap2022_strongTFs')).mark_rect().encode(
    alt.X('variable', title='TFs'),
    alt.Y('index', title="TFs"),
    alt.Color('value', title='es/bg'),
    alt.Tooltip(['index', 'variable','value'])
).properties(height=300, width=300)
)
# Out:
# alt.HConcatChart(...)

# %%
alt.Chart(hm_diceesoverbg.query('variable == @remap2022_TSStfs & index == @remap2022_TSStfs')).mark_rect().encode(
    alt.X('variable', title='', axis=alt.Axis(labelFontSize=25, titleFontSize=25)),
    alt.Y('index', title="" , axis=alt.Axis(labelFontSize=25, titleFontSize=25)),
    alt.Color('value', title='escape/background', scale=alt.Scale(scheme='lightgreyred')),
    alt.Tooltip(['index', 'variable','value'])
).properties(height=800, width=800).configure_title(fontSize=40, anchor='start').configure_axis(
    labelFontSize=25, 
    titleFontSize=25,
).configure_legend(
titleFontSize=20,
labelFontSize=20,
gradientLength=250,
gradientThickness=40,
titleLimit=200)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### SUMMARY - Stats

# %%
def __stat_mat(tflist, escape_dir, total_size):
    fisher_mat = pd.DataFrame(index=tflist, columns=tflist)

    tflist_pop = tflist.copy()
    for t in tflist:
        tfile = pd.read_table(os.path.join(escape_dir, t + ".bed.gz"), names=TSS_bedcols)
        tfile_size = tfile.shape[0]

        if tfile_size == 0:
            fisher_mat.loc[t] = np.nan
            fisher_mat.loc[:, t] = np.nan

            tflist_pop.pop(0)
            continue

        for t2 in tflist_pop:
            chi_df = pd.DataFrame(index=['A_B', 'A_notB', 'notA_B', "notA_notB"], columns=['obs', 'exp'])
            t2file = pd.read_table(os.path.join(escape_dir, t2 + ".bed.gz"), names=TSS_bedcols)
            t2file_size = t2file.shape[0]
            #print('t2 = ', t2)

            if t2file_size == 0:
                fisher_mat.loc[t, t2] = np.nan
                fisher_mat.loc[t2, t] = np.nan

            else:
                inner = tfile.merge(t2file, how='inner').shape[0]

                A_only = tfile_size - inner
                B_only = t2file_size - inner

                chi_df.loc['A_B', 'obs'] = inner
                chi_df.loc['A_notB', 'obs'] = A_only
                chi_df.loc['B_notA', 'obs'] = B_only
                chi_df.loc['notA_notB', 'obs'] = total_size - inner - A_only - B_only
                chi_df.loc['A_B', 'exp'] = tfile_size * t2file_size / total_size
                chi_df.loc['A_notB', 'exp'] = tfile_size * (total_size - t2file_size) / total_size
                chi_df.loc['B_notA', 'exp'] = t2file_size * (total_size - tfile_size) / total_size
                chi_df.loc['notA_notB', 'exp'] = (total_size - t2file_size) * (total_size - tfile_size) / total_size

                odds, fisher_pval = fisher_exact([[inner, A_only], [B_only, chi_df.loc['notA_notB', 'obs']]])                
                fisher_mat.loc[t, t2] = fisher_pval
                fisher_mat.loc[t2, t] = fisher_pval

        tflist_pop.pop(0)

    fisher_mat = fisher_mat.astype(float)
    np.fill_diagonal(fisher_mat.values, 1.01)

    return fisher_mat

# %%
fe_allvsall = __stat_mat(remap2022_TFs, escapeoverlapdir, 55)
fe_bg_allvsall = __stat_mat(remap2022_TFs, bgoverlapdir, 275)

# %%
tf_pairs_sum = pd.DataFrame({'pairs':tf_pairs}).sort_values('pairs')

FDR = 0.10

for i, row in tf_pairs_sum.iterrows():
    p = row[0]
    tf_pairs_sum.loc[i, 'tf1'] = p[0]
    tf_pairs_sum.loc[i, 'tf2'] = p[1]
    tf_pairs_sum.loc[i, 'sim_esoverbg'] = sim_foreoverbg.loc[p[0], p[1]]
    tf_pairs_sum.loc[i, 'dice_esoverbg'] = dice_foreoverbg.loc[p[0], p[1]]

    tf_pairs_sum.loc[i, 'es_fepval'] = fe_allvsall.loc[p[0], p[1]]
    tf_pairs_sum.loc[i, 'bg_fepval'] = fe_bg_allvsall.loc[p[0], p[1]]

tf_pairs_sum = tf_pairs_sum.merge(meta[['TF_Name', 'protein_class']], left_on='tf1', right_on='TF_Name', how='left').drop(columns=['TF_Name']).rename(columns={'protein_class':'tf1_class'})
tf_pairs_sum = tf_pairs_sum.merge(meta[['TF_Name', 'protein_class']], left_on='tf2', right_on='TF_Name', how='left').drop(columns=['TF_Name']).rename(columns={'protein_class':'tf2_class'})
tf_pairs_sum

tf_pairs_sum['esfepval_rank'] = tf_pairs_sum[['es_fepval']].rank(method="min")
tf_pairs_sum['bgfepval_rank'] = tf_pairs_sum[['bg_fepval']].rank(method="min")
tf_pairs_sum['BH_esfepval'] = tf_pairs_sum['esfepval_rank'] / tf_pairs_sum['esfepval_rank'].max() * FDR

tf_pairs_sum['BH_bgfepval'] = tf_pairs_sum['bgfepval_rank'].max() / tf_pairs_sum['bgfepval_rank'] * tf_pairs_sum['bg_fepval']

clean_cols = ['pairs', 'tf1', 'tf2', 'tf1_class', 'tf2_class', 'sim_esoverbg', 'dice_esoverbg', 'es_fepval', 'BH_esfepval', 'BH_bgfepval']

# %%
tf_pairs_sum['log_BH_esfepval'] = pd.Series(map(np.log10, tf_pairs_sum['BH_esfepval'])) * -1
tf_pairs_sum['log_BH_bgfepval'] = pd.Series(map(np.log10, tf_pairs_sum['BH_bgfepval'])) * -1

# %%
strongpairs = tf_pairs_sum.query('tf1 == @remap2022_TSStfs & tf2 == @remap2022_TSStfs')[clean_cols].query('tf1 == @remap2022_strongTFs | tf2 == @remap2022_strongTFs').query('dice_esoverbg >= 1.5 & BH_esfepval > es_fepval')
strongpairs['tf1'].append(strongpairs['tf2']).value_counts()
strongpairs.sort_values('dice_esoverbg', ascending=False)
# Out:
#                   pairs    tf1      tf2  \
# 6970      [IRF5, ZFP36]   IRF5    ZFP36
# 6460      [HSF1, ZFP36]   HSF1    ZFP36
# 2190     [BRCA1, ZFP36]  BRCA1    ZFP36
# 8415         [MYB, TBP]    MYB      TBP
# 7360      [MAFF, ZFP36]   MAFF    ZFP36
# 2130     [BRCA1, NIPBL]  BRCA1    NIPBL
# 11100    [STAT1, ZFP36]  STAT1    ZFP36
# 9173     [NIPBL, RBBP5]  NIPBL    RBBP5
# 6455      [HSF1, ZBED1]   HSF1    ZBED1
# 11620     [UBTF, ZFP36]   UBTF    ZFP36
# 7300      [MAFF, NIPBL]   MAFF    NIPBL
# 8365         [MYB, MYC]    MYB      MYC
# 8388       [MYB, RBBP5]    MYB    RBBP5
# 11081      [STAT1, TBP]  STAT1      TBP
# 7333      [MAFF, STAT1]   MAFF    STAT1
# 2099      [BRCA1, HSF1]  BRCA1     HSF1
# 8423        [MYB, UBTF]    MYB     UBTF
# 6910      [IRF5, NIPBL]   IRF5    NIPBL
# 6158      [HDAC2, HSF1]  HDAC2     HSF1
# 7290        [MAFF, MYB]   MAFF      MYB
# 9219     [NIPBL, ZFP36]  NIPBL    ZFP36
# 9222     [NIPBL, ZNF18]  NIPBL    ZNF18
# 6900        [IRF5, MYB]   IRF5      MYB
# 11832    [ZFP36, ZNF18]  ZFP36    ZNF18
# 8490       [MYC, STAT1]    MYC    STAT1
# 9199   [NIPBL, TBL1XR1]  NIPBL  TBL1XR1
# 6374       [HSF1, IRF5]   HSF1     IRF5
# 6400      [HSF1, NIPBL]   HSF1    NIPBL
# 11095    [STAT1, ZBED1]  STAT1    ZBED1
# 9200       [NIPBL, TBP]  NIPBL      TBP
# 11392      [TBP, ZFP36]    TBP    ZFP36
# 8457       [MYC, NIPBL]    MYC    NIPBL
# 8414     [MYB, TBL1XR1]    MYB  TBL1XR1
# 9192     [NIPBL, STAT1]  NIPBL    STAT1
# 6414      [HSF1, RBBP5]   HSF1    RBBP5
# 9208      [NIPBL, UBTF]  NIPBL     UBTF
# 595       [ATF2, ZFP36]   ATF2    ZFP36
# 11089     [STAT1, UBTF]  STAT1     UBTF
# 2120       [BRCA1, MYB]  BRCA1      MYB
# 8407       [MYB, STAT1]    MYB    STAT1
#
#                                                tf1_class  \
# 6970          winged helix/forkhead transcription factor
# 6460          winged helix/forkhead transcription factor
# 2190                            ubiquitin-protein ligase
# 8415                                                 NaN
# 7360           basic leucine zipper transcription factor
# 2130                            ubiquitin-protein ligase
# 11100                   DNA-binding transcription factor
# 9173   chromatin/chromatin-binding, or -regulatory pr...
# 6455          winged helix/forkhead transcription factor
# 11620                   DNA-binding transcription factor
# 7300           basic leucine zipper transcription factor
# 8365                                                 NaN
# 8388                                                 NaN
# 11081                   DNA-binding transcription factor
# 7333           basic leucine zipper transcription factor
# 2099                            ubiquitin-protein ligase
# 8423                                                 NaN
# 6910          winged helix/forkhead transcription factor
# 6158                            histone modifying enzyme
# 7290           basic leucine zipper transcription factor
# 9219   chromatin/chromatin-binding, or -regulatory pr...
# 9222   chromatin/chromatin-binding, or -regulatory pr...
# 6900          winged helix/forkhead transcription factor
# 11832                             RNA metabolism protein
# 8490         basic helix-loop-helix transcription factor
# 9199   chromatin/chromatin-binding, or -regulatory pr...
# 6374          winged helix/forkhead transcription factor
# 6400          winged helix/forkhead transcription factor
# 11095                   DNA-binding transcription factor
# 9200   chromatin/chromatin-binding, or -regulatory pr...
# 11392                       general transcription factor
# 8457         basic helix-loop-helix transcription factor
# 8414                                                 NaN
# 9192   chromatin/chromatin-binding, or -regulatory pr...
# 6414          winged helix/forkhead transcription factor
# 9208   chromatin/chromatin-binding, or -regulatory pr...
# 595            basic leucine zipper transcription factor
# 11089                   DNA-binding transcription factor
# 2120                            ubiquitin-protein ligase
# 8407                                                 NaN
#
#                                                tf2_class  sim_esoverbg  \
# 6970                              RNA metabolism protein      2.705882
# 6460                              RNA metabolism protein      2.750000
# 2190                              RNA metabolism protein      2.500000
# 8415                        general transcription factor      2.650000
# 7360                              RNA metabolism protein      2.294118
# 2130   chromatin/chromatin-binding, or -regulatory pr...      2.285714
# 11100                             RNA metabolism protein      2.296651
# 9173                                                 NaN      2.071429
# 6455                              DNA metabolism protein      2.214286
# 11620                             RNA metabolism protein      2.087719
# 7300   chromatin/chromatin-binding, or -regulatory pr...      2.187500
# 8365         basic helix-loop-helix transcription factor      2.048309
# 8388                                                 NaN      1.928571
# 11081                       general transcription factor      2.136364
# 7333                    DNA-binding transcription factor      1.937500
# 2099          winged helix/forkhead transcription factor      2.000000
# 8423                    DNA-binding transcription factor      2.062500
# 6910   chromatin/chromatin-binding, or -regulatory pr...      2.000000
# 6158          winged helix/forkhead transcription factor      1.928571
# 7290                                                 NaN      2.020408
# 9219                              RNA metabolism protein      1.964286
# 9222               C2H2 zinc finger transcription factor      1.986928
# 6900                                                 NaN      1.857143
# 11832              C2H2 zinc finger transcription factor      1.890000
# 8490                    DNA-binding transcription factor      1.922727
# 9199                                                 NaN      1.785714
# 6374          winged helix/forkhead transcription factor      1.893939
# 6400   chromatin/chromatin-binding, or -regulatory pr...      2.000000
# 11095                             DNA metabolism protein      1.750000
# 9200                        general transcription factor      1.973684
# 11392                             RNA metabolism protein      1.924812
# 8457   chromatin/chromatin-binding, or -regulatory pr...      1.818182
# 8414                                                 NaN      1.692308
# 9192                    DNA-binding transcription factor      1.833333
# 6414                                                 NaN      1.687500
# 9208                    DNA-binding transcription factor      1.714286
# 595                               RNA metabolism protein      1.750000
# 11089                   DNA-binding transcription factor      1.857143
# 2120                                                 NaN      1.657143
# 8407                    DNA-binding transcription factor      1.684211
#
#        dice_esoverbg     es_fepval  BH_esfepval   BH_bgfepval
# 6970        2.380952  2.165944e-02     0.045231  3.403370e-02
# 6460        2.166667  7.349317e-05     0.016504  1.473626e-03
# 2190        2.142857  1.255619e-03     0.026219  8.049930e-03
# 8415        2.100000  1.192139e-04     0.017707  7.960019e-04
# 7360        1.956522  1.595405e-03     0.027473  4.411313e-03
# 2130        1.947368  5.754923e-04     0.023141  4.456554e-03
# 11100       1.849530  5.271102e-05     0.015605  7.109672e-06
# 9173        1.833333  2.935010e-03     0.030589  5.958426e-03
# 6455        1.809524  1.017998e-04     0.017213  1.365080e-04
# 11620       1.794872  3.916112e-03     0.032046  8.454345e-04
# 7300        1.791667  1.691243e-05     0.012818  1.070964e-04
# 8365        1.777778  1.806075e-02     0.043293  3.166947e-03
# 8388        1.764706  3.731656e-02     0.050906  3.171744e-02
# 11081       1.757576  1.192139e-04     0.017707  5.479631e-06
# 7333        1.750000  4.627310e-02     0.052844  2.993988e-02
# 2099        1.750000  4.306706e-03     0.032350  3.080595e-03
# 8423        1.739130  7.124467e-04     0.023952  3.788101e-04
# 6910        1.736842  5.754923e-04     0.023141  5.038878e-04
# 6158        1.722222  2.379286e-02     0.046029  4.423694e-03
# 7290        1.714286  3.636171e-04     0.021507  3.789215e-04
# 9219        1.675000  1.673719e-03     0.027802  1.264847e-04
# 9222        1.671111  2.816049e-04     0.020735  6.931508e-05
# 6900        1.666667  9.002343e-03     0.037923  3.765381e-03
# 11832       1.659259  8.920454e-03     0.037834  9.782499e-04
# 8490        1.654839  2.462128e-03     0.030019  4.276230e-05
# 9199        1.647059  1.387460e-02     0.040519  1.562647e-03
# 6374        1.614583  1.328059e-04     0.018075  1.561589e-05
# 6400        1.600000  3.460407e-07     0.006852  7.182638e-08
# 11095       1.600000  4.627310e-02     0.052894  1.628352e-02
# 9200        1.596774  1.020153e-06     0.008220  1.575372e-08
# 11392       1.588517  1.604505e-05     0.012717  6.612424e-07
# 8457        1.562500  7.235369e-04     0.024066  1.068367e-05
# 8414        1.562500  1.090147e-02     0.038835  1.087900e-03
# 9192        1.555556  1.472698e-04     0.018531  5.521982e-06
# 6414        1.550000  2.225448e-02     0.045573  4.422673e-03
# 9208        1.535714  1.173540e-02     0.039430  8.798549e-04
# 595         1.531250  3.770061e-04     0.021685  1.369513e-05
# 11089       1.521739  1.036492e-06     0.008296  2.068924e-07
# 2120        1.511111  9.002343e-03     0.037923  2.523605e-03
# 8407        1.500000  7.014938e-03     0.036048  2.528729e-04
